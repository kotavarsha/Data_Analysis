# %%
#K.Varsha

# %% [markdown]
# # DistrictswiseCR_AEdataf_24-25
# This dataset appears to contain information about case registrations and advice-enabled services across different states and
# districts in India for the year 2024-2025. It categorizes data based on different parameters such as gender, caste, and the
# number of Common Service Centers (CSCs).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("DistrictswiseCR_AEdataf_24-25.csv")
df
# Out:
#                   Category             States/UT's                 Districts  \
# 0          Case Registered     Andaman and Nicobar                   Nicobar
# 1          Case Registered     Andaman and Nicobar  North and Middle Andaman
# 2          Case Registered     Andaman and Nicobar             South Andaman
# 3          Case Registered          Andhra Pradesh     Alluri Sitharama Raju
# 4          Case Registered          Andhra Pradesh                Anakapalli
# ...                    ...                     ...                       ...
# 1567        Advice Enabled             West Bengal            PurbaBardhaman
# 1568        Advice Enabled             West Bengal                   Purulia
# 1569        Advice Enabled             West Bengal        South 24 Paraganas
# 1570        Advice Enabled             West Bengal            West Medinipur
# 1571  Total Advice Enabled  Total (36 States/UT's)      Tota (785 Districts)
#
# ...

# %% [markdown]
# provides metadata about the dataset
# Number of rows & columns
# Column names & data types
# Missing values count
# Memory usage

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1572 entries, 0 to 1571
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Category     1572 non-null   object
#  1   States/UT's  1572 non-null   object
#  2   Districts    1572 non-null   object
#  3   No. of CSCs  1572 non-null   int64
#  4   Female       1572 non-null   int64
#  5   Male         1572 non-null   int64
#  6   Total        1572 non-null   int64
#  7   General      1572 non-null   int64
#  8   OBC          1572 non-null   int64
#  9   SC           1572 non-null   int64
#  10  ST           1572 non-null   int64
#  11  Total.1      1572 non-null   int64
# dtypes: int64(9), object(3)
# memory usage: 147.5+ KB
# None

# %%
display(df.isnull().sum())
# Out:
# Category       0
# States/UT's    0
# Districts      0
# No. of CSCs    0
# Female         0
# Male           0
# Total          0
# General        0
# OBC            0
# SC             0
# ST             0
# Total.1        0
# dtype: int64

# %%
display(df.describe())
# Out:
#          No. of CSCs        Female          Male         Total       General  \
# count    1572.000000  1.572000e+03  1.572000e+03  1.572000e+03  1.572000e+03
# mean      636.132316  1.015027e+04  1.581586e+04  2.596613e+04  6.030291e+03
# std      8907.104216  1.422710e+05  2.217056e+05  3.639101e+05  8.458425e+04
# min         1.000000  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%       100.000000  8.307500e+02  1.292750e+03  2.243250e+03  3.060000e+02
# 50%       248.500000  2.342500e+03  3.713500e+03  6.238000e+03  1.305000e+03
# 75%       470.000000  6.185250e+03  9.239250e+03  1.583775e+04  3.403750e+03
# max    250000.000000  4.014611e+06  6.247980e+06  1.026259e+07  2.387060e+06
#
#                 OBC            SC            ST       Total.1
# count  1.572000e+03  1.572000e+03  1.572000e+03  1.572000e+03
# mean   8.225906e+03  8.219697e+03  3.490233e+03  2.596613e+04
# std    1.154120e+05  1.152801e+05  4.899153e+04  3.639101e+05
# ...

# %% [markdown]
# Aggregates case counts for different categories (General, OBC, SC).

# %%
df_grouped_state = df.groupby("Category")["General","OBC","SC"].sum()
display(df_grouped_state)
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_30456\3969537767.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_grouped_state = df.groupby("Category")["General","OBC","SC"].sum()
#                        General      OBC       SC
# Category
# Advice Enabled         2352749  3213067  3214657
# Case Registered        2387060  3252495  3246025
# Total Advice Enabled   2352749  3213067  3214657
# Total Case Registered  2387060  3252495  3246025

# %%
Visualizes the count of cases in the General category using a bar chart.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df_grouped_state.index, y=df_grouped_state["General"], palette="viridis")
plt.xticks(rotation=90)
plt.title("General category")
plt.xlabel("category")
plt.ylabel("Count")
plt.show()

# %%
Displays a heatmap showing case distribution across categories and caste groups.

# %%
plt.figure(figsize=(8, 5))
heatmap_data = df.groupby("Category")[["General", "OBC", "SC", "ST"]].sum()
sns.heatmap(heatmap_data, cmap="coolwarm", annot=True, fmt="d", linewidths=0.5)
plt.title("Heatmap of Case Distribution Across Categories & Caste Groups")
plt.xlabel("Caste Group")
plt.ylabel("Category")
plt.show()

# %%
Shows the proportion of male and female cases in a pie chart.

# %%
df_gender_total = df.groupby("Category")[["Male", "Female"]].sum().sum()
plt.figure(figsize=(6, 6))
plt.pie(
    df_gender_total, 
    labels=["Male", "Female"], 
    autopct="%1.1f%%", 
    colors=["#3498db", "#e74c3c"], 
    startangle=90
)
# Out:
# ([<matplotlib.patches.Wedge at 0x21e2f507c10>,
# ...
#  [Text(-1.0360231062972174, -0.3696702898777032, 'Male'),
#   Text(1.036023140908243, 0.36967019287821823, 'Female')],
#  [Text(-0.5651035125257549, -0.2016383399332926, '60.9%'),
#   Text(0.5651035314044961, 0.20163828702448264, '39.1%')])

# %%
Plots the total number of cases for each state using a line chart.

# %%
plt.figure(figsize=(12, 5))
statewise_cases = df.groupby("States/UT's")["Total"].sum().sort_values()
statewise_cases.plot(kind="line", marker="o", color="b", linestyle="-", linewidth=2)
plt.title("Total Cases Across States")
plt.xlabel("States/UTs")
plt.ylabel("Total Cases")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
Displays outliers in case registrations and advice-enabled cases.

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=df["Total"], x=df["Category"], palette="pastel")
plt.title("Outlier Analysis: Case Registrations & Advice Enabled")
plt.xlabel("Category")
plt.ylabel("Total Cases")
plt.show()

# %%
 Bar chart showing the states with the highest number of Common Service Centers (CSCs).

# %%
df.groupby("States/UT's")["No. of CSCs"].sum().sort_values(ascending=False).head(10).plot(
    kind="bar", color="skyblue", title="Top 10 States by Number of CSCs"
)
# Out:
# <AxesSubplot:title={'center':'Top 10 States by Number of CSCs'}, xlabel="States/UT's">

# %%
Bar plot comparing male and female cases.

# %%
df[["Female", "Male"]].sum().plot(
    kind="bar", color=["pink", "blue"], title="Overall Gender Distribution"
)
# Out:
# <AxesSubplot:title={'center':'Overall Gender Distribution'}>

# %%
df.groupby("States/UT's")["Total"].sum().sort_values(ascending=False).head(10).plot(
    kind="bar", color="orange", title="Top 10 States by Total Cases"
)
# Out:
# <AxesSubplot:title={'center':'Top 10 States by Total Cases'}, xlabel="States/UT's">

# %%
df["Category"].value_counts().plot(
    kind="pie", autopct="%1.1f%%", startangle=90, title="Category Distribution"
)
# Out:
# <AxesSubplot:title={'center':'Category Distribution'}, ylabel='Category'>

# %%
df[["General", "OBC", "SC", "ST"]].sum().plot(
    kind="bar", color=["red", "green", "blue", "purple"], title="Caste-wise Distribution"
)
# Out:
# <AxesSubplot:title={'center':'Caste-wise Distribution'}>

# %%
sns.boxplot(y=df["Total"]).set(title="Distribution of Total Cases")
# Out:
# [Text(0.5, 1.0, 'Distribution of Total Cases')]

# %%
df.groupby("Districts")["Total"].sum().sort_values(ascending=False).head(10).plot(
    kind="barh", color="teal", title="Top 10 Districts by Total Cases"
)
# Out:
# <AxesSubplot:title={'center':'Top 10 Districts by Total Cases'}, ylabel='Districts'>

# %%
top_states = df.groupby("States/UT's")["Total"].sum().sort_values(ascending=False).head(10).index
df[df["States/UT's"].isin(top_states)].groupby("States/UT's")[["Female", "Male"]].sum().plot(
    kind="bar", stacked=True, title="Gender-wise Distribution in Top 10 States"
)
# Out:
# <AxesSubplot:title={'center':'Gender-wise Distribution in Top 10 States'}, xlabel="States/UT's">

# %%
Displays correlations between different caste categories.

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df_grouped_state.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Between Category")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x=df["OBC"], y=df["SC"], hue=df["Category"], palette="tab10")
plt.title("OBC vs SC")
plt.xlabel("OBC")
plt.ylabel("SC")
plt.show()

# %%
plt.figure(figsize=(12,6))
df_grouped_district = df.groupby("Districts")["Female", "Male"].sum()
df_grouped_district.sort_values("Female", ascending=False).head(10).plot(kind="bar", figsize=(12,6))
plt.title("Top 10 Districts by Female")
plt.xlabel("Districst")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_30456\2294261082.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_grouped_district = df.groupby("Districts")["Female", "Male"].sum()

# %%
top_5_states = df_grouped_state.sort_values("General", ascending=False).head(5)
display(top_5_states)
# Out:
#                        General      OBC       SC
# Category
# Case Registered        2387060  3252495  3246025
# Total Case Registered  2387060  3252495  3246025
# Advice Enabled         2352749  3213067  3214657
# Total Advice Enabled   2352749  3213067  3214657

# %%
df_grouped_state["Cast"] = (df_grouped_state["OBC"] / df_grouped_state["SC"]) * 100
display(df_grouped_state[["Cast"]].sort_values("Cast", ascending=False))
# Out:
#                              Cast
# Category
# Case Registered        100.199321
# Total Case Registered  100.199321
# Advice Enabled          99.950539
# Total Advice Enabled    99.950539

# %%
plt.figure(figsize=(8,8))
df_grouped_state["General"].plot(kind="pie", autopct="%1.1f%%", cmap="Set3")
plt.title("Percentage of General")
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(12,6))
df_grouped_state[["OBC", "SC"]].plot(kind="line", marker='o', figsize=(12,6))

plt.xlabel("State")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
Analyzes the relationship between female and male cases.

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=df, x="General", y="SC", label="Initiated", marker='o')
sns.lineplot(data=df, x="General", y="ST", label="Approved", marker='s')
plt.title("District wise over the year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
df_grouped_district["Gender"] = (df_grouped_district["Female"] / df_grouped_district["Male"]) * 100
display(df_grouped_district[["Gender"]].sort_values("Gender", ascending=False))
# Out:
#                    Gender
# Districts
# Jiribam               inf
# Kakching              inf
# Sakti         2237.500000
# Slumber       1100.000000
# Jaipur Rural   722.580645
# ...                   ...
# Shamator              NaN
# Shi Yomi              NaN
# Siang                 NaN
# Tengnoupal            NaN
# Tseminyu              NaN
#
# [791 rows x 1 columns]

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df_grouped_district.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Male and Female at District Level")
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.lineplot(x="Female", y="Male", hue="General", data=df, marker="o")
plt.xticks(rotation=90)
plt.title("general of Female and male")
plt.xlabel("Female")
plt.ylabel("Male")
plt.legend(title="Products", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
total_initiated = df["Female"].sum()
total_approved = df["Male"].sum()

approval_accuracy = (total_approved / total_initiated) * 100
print(f"Overall Approval Accuracy: {approval_accuracy:.2f}%")
# Out:
# Overall Approval Accuracy: 155.82%

# %% [markdown]
# Observations from the Dataset: "DistrictswiseCR_AEdataf_24-25.csv"
# The dataset differentiates between cases registered and advice-enabled services in each district.
# Some states have more advice-enabled cases than registered cases, indicating people are seeking legal advice before registering cases.
# The dataset categorizes cases into General, OBC, SC, and ST categories.
# SC & ST communities have a significant number of registered cases, highlighting legal challenges in these communities.
# Some states have higher case registration for OBC groups, indicating caste-related legal issues may vary by region.
# Certain states/districts have higher case registration rates, indicating high legal activity.
# Some regions show low case registration but high advice-enabled cases, suggesting people are seeking guidance rather than taking legal action.
# Differences in legal participation across states may be influenced by local policies, awareness campaigns, or socio-economic factors.
