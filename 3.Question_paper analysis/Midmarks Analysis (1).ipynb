# %%
#K.Varsha

# %% [markdown]
# # MID MARKS
#
#  midterm exam marks stored in a dataset (MIDMARKS.csv). It uses data processing and statistical analysis techniques to gain insights into student performance across different sections. The script cleans and processes the data, computes statistics such as means and standard deviations, performs hypothesis testing (t-tests and chi-square tests), and visualizes student scores through histograms, pie charts, and line graphs. Additionally, it calculates pass probabilities, assigns grades, and identifies students with backlogs.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("MIDMARKS.csv")

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df['SECTION'] = df['SECTION'].fillna('SIGMA') 
df['SECTION'] = df['SECTION'].replace('','SIGMA')
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df['S.NO'] = range(1,len(df) + 1)
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df['FL'] = df['FL'].fillna(0) 
df=df.dropna()

# %%
df.info
# Out:
# <bound method DataFrame.info of      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]>

# %% [markdown]
#  Mid Marks Data

# %%
df.shape
# Out:
# (716, 8)

# %%
import pandas as pd
from scipy.stats import ttest_ind

# %%
a=df[df["SECTION"] == "ALPHA"]["DV"]
b=df[df["SECTION"] == "BETA"]["DV"]
ttest_ind(a,b)
# Out:
# Ttest_indResult(statistic=0.6207084248259586, pvalue=0.5355854399866022)

# %%
import pandas as pd
from scipy.stats import ttest_ind
a=df[df["SECTION"] == "ALPHA"]["DV"]
b=df[df["SECTION"] == "BETA"]["DV"]
ttest_ind(a,b)
# Out:
# Ttest_indResult(statistic=0.6207084248259586, pvalue=0.5355854399866022)

# %%
a=df[df["SECTION"] == "ALPHA"]["DV"]
b=df[df["SECTION"] == "BETA"]["DV"]
ttest_ind(a,b)
# Out:
# Ttest_indResult(statistic=0.6207084248259586, pvalue=0.5355854399866022)

# %%
from scipy.stats import chi2_contingency
a=df[df["SECTION"] == "ALPHA"]["DV"]
b=df[df["SECTION"] == "BETA"]["DV"]
stat,p,dof,expected=chi2_contingency(a,b)
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# p value is 1.0
# Independent (H0 holds true)

# %%
df[df["SECTION"]=="ALPHA"].mean()
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_44508\257320406.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df["SECTION"]=="ALPHA"].mean()
# S.NO     4.550000e+01
# DV      1.354646e+160
# M-II    1.349908e+158
# dtype: float64

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("MIDMARKS.csv")  # Ensure the correct file path

# Convert the "DV" column to numeric (if not already)
df["DV"] = pd.to_numeric(df["DV"], errors="coerce")

# Calculate the sample mean for the "ALPHA" section
alpha_dv_mean = df[df["SECTION"] == "ALPHA"]["DV"].mean()
population_dv_mean=df["DV"].mean

# %%
population_dv_mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0      12.0
# 1      19.0
# 2      18.0
# 3      15.0
# 4      18.0
#        ...
# 713    19.0
# 714    12.0
# 715    17.0
# 716    12.0
# 717    19.0
# Name: DV, Length: 718, dtype: float64>

# %%
std_data=df[df["SECTION"]=="ALPHA"].std()
std_data
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_44508\1606161487.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   std_data=df[df["SECTION"]=="ALPHA"].std()
# S.NO    26.124701
# DV       4.991891
# dtype: float64

# %%
df.DV.mean(
)
# Out:
# 15.018439716312058

# %%
df.rename(columns={'M-II':'M2'},inplace=True)

# %% [markdown]
# Renaming M-II as M2

# %%
df
# Out:
#      S.NO SECTION    DV  M2  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12.0   0  17    9  19   15
# 1     2.0   ALPHA  19.0  12  16   16  18    3
# 2     3.0   ALPHA  18.0  14  18   18  18   16
# 3     4.0   ALPHA  15.0   9  19   17  19   15
# 4     5.0   ALPHA  18.0  17  19   19  20   18
# ..    ...     ...   ...  ..  ..  ...  ..  ...
# 713   NaN    ZETA  19.0   8   8   19  17   18
# 714   NaN    ZETA  12.0   1   7   10  20    8
# 715   NaN    ZETA  17.0   6  14   14  17   18
# 716   NaN    ZETA  12.0   1   6    7  15   12
# 717   NaN    ZETA  19.0  14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df['DV'] = pd.to_numeric(df['DV'], errors='coerce')
df['M2'] = pd.to_numeric(df['M2'], errors='coerce')
df['PP'] = pd.to_numeric(df['PP'], errors='coerce')
df['BEEE'] = pd.to_numeric(df['BEEE'], errors='coerce')
df['FL'] = pd.to_numeric(df['FL'], errors='coerce')
df['FIMS'] = pd.to_numeric(df['FIMS'], errors='coerce')
df.fillna(0, inplace=True)

# %%
df['Total'] = df['DV'] + df['M2'] + df['PP'] + df['BEEE'] + df['FL'] + df['FIMS']

df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Total
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0
#
# [718 rows x 9 columns]

# %% [markdown]
# Calculating total

# %%
df["Percentage"] = (df['Total']/120)*100

# %%
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Total  Percentage
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   60.000000
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   70.000000
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0   85.000000
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   78.333333
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0   92.500000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   74.166667
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   48.333333
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   71.666667
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   44.166667
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   87.500000
#
# [718 rows x 10 columns]

# %%
df['Percentage'] = df['Percentage'].round().astype(int)
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Total  Percentage
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0          60
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0          70
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0          85
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0          78
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0          92
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0          74
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0          48
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0          72
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0          44
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0          88
#
# [718 rows x 10 columns]

# %%
def assign_grade(percentage):
    if percentage >= 90:
        return 'A'
    elif percentage >= 80:
        return 'B+'
    elif percentage >= 70:
        return 'B'
    elif percentage >= 60:
        return 'C+'
    elif percentage >=50:
        return 'C'
    elif percentage >=40:
        return 'D'
    else:
        return 'F'
df['Grade'] = df['Percentage'].apply(assign_grade)
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Total  Percentage Grade
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0          60    C+
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0          70     B
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0          85    B+
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0          78     B
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0          92     A
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...   ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0          74     B
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0          48     D
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0          72     B
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0          44     D
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0          88    B+
#
# [718 rows x 11 columns]

# %%
df.plot()
plt.show()

# %%
plt.figure(figsize=[8, 4])
plt.hist(df['Total'], color='cyan', bins=10, edgecolor='black')
plt.title("Distribution of Total Marks")
plt.xlabel("Total Marks")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# Most of the students scored marks in between 80 and 100

# %%
df['DV'] = pd.to_numeric(df['DV'], errors='coerce')
df = df.dropna(subset=['DV'])
plt.hist(df['DV'], bins=10, color='red', edgecolor='black')
plt.title("Distribution of DV Marks")
plt.xlabel("DV Marks")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# More than 120 students scored 20 marks in M2 subject

# %%
filtered_df = df[df['PP'] > 10]
plt.hist(filtered_df['PP'], bins=10, color='blue', edgecolor='black')
plt.title("PP Marks above 15 ")
plt.xlabel("PP Marks")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
#  PP Marks who got more than 10

# %% [markdown]
# M2 Marks Who got less than 10

# %%
filtered_df = df[df['PP'] < 10]

plt.scatter(filtered_df.index, filtered_df['PP'], alpha=0.7, color='green')
plt.title("Less than 10 Marks in PP")
plt.xlabel("Student Index")
plt.ylabel("PP Marks")
plt.show()

# %% [markdown]
# Scoring of PP Marks Less than 10

# %%
filtered_df = df[df['BEEE'] < 10]

plt.scatter(filtered_df.index, filtered_df['PP'], alpha=0.7, color='blue')
plt.title("More than 10 Marks in BEEE")
plt.xlabel("Student Index")
plt.ylabel("BEEE Marks")
plt.show()

# %% [markdown]
# Scoring of BEEE Marks More than 15

# %% [markdown]
# # Students who scored 10 marks in DV

# %%
filtered_df = df[df['M2'] == 0]
plt.scatter(filtered_df.index, filtered_df['DV'], alpha=0.7, color='grey')
plt.title("Students Marks 0 in M2 ")
plt.xlabel("Student Index")
plt.ylabel("M2 Marks")
plt.show()

# %% [markdown]
#  Students who scored 0 Marks in M2

# %%
plt.figure(figsize=(5, 6))
sns.boxplot(data=df['DV'], color='lightblue')
plt.title("Box Plot of DV Marks")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# # Box plot for the DV Marks

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df['BEEE'], color='lightgreen')
plt.title("Box Plot of BEEE Marks")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
#  Box plot of BEEE Marks

# %%
a.plot.line(x='DV',y='Total',color='red')
plt.title("Line Graph of DV")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Lineplot for total and DV

# %%
a.plot.line(x='FIMS',y='Total',color='red')
plt.title("Line Graph of FIMS")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Lineplot for total and FIMS

# %%
a.plot.line(x='M2',y='Total',color='blue')
plt.title("Line Graph of M2")
plt.ylabel("Total")
plt.show()

# %% [markdown]
#  Lineplot for total and M2

# %%
a.plot.line(x='BEEE',y='Total',color='blue')
plt.title("Line Graph of BEEE")
plt.ylabel("Total")
plt.show()

# %% [markdown]
#  Lineplot for total and BEEE

# %% [markdown]
#  students between 115 and 120

# %%
b['DV'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of DV")
# Out:
# Text(0.5, 1.0, 'Pie Chart of DV')

# %% [markdown]
#  PIE Chart of DV for 32 students

# %%
b['BEEE'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of BEEE")
# Out:
# Text(0.5, 1.0, 'Pie Chart of BEEE')

# %% [markdown]
#  PIE Chart of BEEE for 32 students

# %%
b['PP'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of PP")
# Out:
# Text(0.5, 1.0, 'Pie Chart of PP')

# %% [markdown]
#  PIE Chart of PP for 32 students

# %%
df.sort_values('Total').tail(10)
# Out:
#       S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Total  Percentage  \
# 521  522.0   OMEGA  20.0  19.0  20.0  19.0  20.0  20.0  118.0          98
# 533  534.0   OMEGA  20.0  19.0  20.0  20.0  20.0  20.0  119.0          99
# 613    0.0       0  20.0  20.0  19.0  20.0  20.0  20.0  119.0          99
# 453  454.0   OMEGA  20.0  20.0  20.0  20.0  20.0  19.0  119.0          99
# 251  252.0   DELTA  20.0  20.0  20.0  19.0  20.0  20.0  119.0          99
# 618    0.0       0  20.0  20.0  20.0  20.0  20.0  19.0  119.0          99
# 574  575.0   SIGMA  20.0  20.0  20.0  20.0  20.0  20.0  120.0         100
# 507  508.0   OMEGA  20.0  20.0  20.0  20.0  20.0  20.0  120.0         100
# 505  506.0   OMEGA  20.0  20.0  20.0  20.0  20.0  20.0  120.0         100
# 596  597.0   SIGMA  20.0  20.0  20.0  20.0  20.0  20.0  120.0         100
#
#     Grade
# 521     A
# 533     A
# 613     A
# 453     A
# 251     A
# 618     A
# 574     A
# 507     A
# 505     A
# 596     A

# %%
df.sort_values('DV').tail(20)
# Out:
#       S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Total  Percentage  \
# 502  503.0   OMEGA  20.0   7.0  17.0  17.0  20.0  18.0   99.0          82
# 505  506.0   OMEGA  20.0  20.0  20.0  20.0  20.0  20.0  120.0         100
# 474  475.0   OMEGA  20.0  18.0  20.0  19.0  20.0  18.0  115.0          96
# 506  507.0   OMEGA  20.0  18.0  20.0  20.0  20.0  19.0  117.0          98
# 510  511.0   OMEGA  20.0   6.0  16.0  11.0  20.0  14.0   87.0          72
# 511  512.0   OMEGA  20.0   6.0  18.0  13.0  20.0  18.0   95.0          79
# 512  513.0   OMEGA  20.0  20.0   5.0  19.0  18.0  14.0   96.0          80
# 513  514.0   OMEGA  20.0  16.0  18.0  19.0  20.0  19.0  112.0          93
# 515  516.0   OMEGA  20.0  15.0  20.0  20.0  20.0  15.0  110.0          92
# 621    0.0       0  20.0  20.0  20.0  16.0  18.0  17.0  111.0          92
# 518  519.0   OMEGA  20.0   1.0  20.0   6.0  14.0  15.0   76.0          63
# 519  520.0   OMEGA  20.0  17.0  20.0  20.0  20.0  17.0  114.0          95
# 618    0.0       0  20.0  20.0  20.0  20.0  20.0  19.0  119.0          99
# 521  522.0   OMEGA  20.0  19.0  20.0  19.0  20.0  20.0  118.0          98
# 522  523.0   OMEGA  20.0  14.0  19.0  19.0  20.0  18.0  110.0          92
# 615    0.0       0  20.0  20.0  17.0  16.0  18.0  18.0  109.0          91
# 614    0.0       0  20.0  19.0  17.0  18.0  20.0  19.0  113.0          94
# 613    0.0       0  20.0  20.0  19.0  20.0  20.0  20.0  119.0          99
# 507  508.0   OMEGA  20.0  20.0  20.0  20.0  20.0  20.0  120.0         100
# 69    70.0   ALPHA  20.0  20.0  20.0  19.0  20.0  18.0  117.0          98
#
#     Grade
# 502    B+
# 505     A
# 474     A
# 506     A
# 510     B
# 511     B
# 512    B+
# 513     A
# 515     A
# 621     A
# 518    C+
# 519     A
# 618     A
# 521     A
# 522     A
# 615     A
# 614     A
# 613     A
# 507     A
# 69      A

# %%
h = df[
    (df['DV'] < 10.0) |
    (df['PP'] < 10.0) |
    (df['M2'] < 10.0) |
    (df['BEEE'] < 10.0) |
    (df['FL'] < 10.0) |
    (df['FIMS'] < 10.0)
]
h['SECTION'].value_counts()
# Out:
# ZETA       69
# EPSILON    67
# OMEGA      62
# DELTA      58
# GAMMA      57
# BETA       54
# ALPHA      39
# SIGMA      26
# 0          13
# Name: SECTION, dtype: int64

# %%
df['backlogs'] = (df[['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']] < 10).sum(axis=1)
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Total  Percentage  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0          60
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0          70
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0          85
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0          78
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0          92
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0          74
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0          48
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0          72
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0          44
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0          88
#
#     Grade  backlogs
# 0      C+         2
# 1       B         1
# 2      B+         0
# 3       B         1
# 4       A         0
# ..    ...       ...
# 713     B         2
# 714     D         3
# 715     B         1
# 716     D         3
# 717    B+         0
#
# [718 rows x 12 columns]

# %%
j.value_counts('backlogs')
# Out:
# backlogs
# 0    273
# 1    172
# 2    121
# 3     69
# 4     43
# 5     23
# 6     17
# dtype: int64

# %%
df.drop(columns="Total")
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Percentage Grade  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0          60    C+
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0          70     B
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0          85    B+
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0          78     B
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0          92     A
# ..    ...     ...   ...   ...   ...   ...   ...   ...         ...   ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0          74     B
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0          48     D
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0          72     B
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0          44     D
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0          88    B+
#
#      backlogs
# 0           2
# 1           1
# 2           0
# 3           1
# 4           0
# ..        ...
# 713         2
# 714         3
# 715         1
# 716         3
# 717         0
#
# [718 rows x 11 columns]

# %%
import pandas as pd

# Load the dataset
file_path = "MIDMARKS.csv"  # Update with the correct file path
df = pd.read_csv(file_path)

# Convert the DV column to numeric, handling errors
df["DV"] = pd.to_numeric(df["DV"], errors="coerce")

# Define the passing mark
passing_mark = 10

# Filter the data for Section Alpha
alpha_df = df[df["SECTION"] == "ALPHA"]

# Calculate pass probability
total_students = len(alpha_df)
students_passed = (alpha_df["DV"] >= passing_mark).sum()
pass_probability = students_passed / total_students

# Output the result
print(f"Pass probability for DV in Section Alpha: {pass_probability:.4f}")
# Out:
# Pass probability for DV in Section Alpha: 0.8111

# %%
import pandas as pd

# Load the dataset
file_path = "MIDMARKS.csv"  # Update with the correct file path
df = pd.read_csv(file_path)

# Convert the DV column to numeric, handling errors
df["DV"] = pd.to_numeric(df["DV"], errors="coerce")

# Define the passing mark
passing_mark = 10

# Filter the data for Section Alpha
alpha_df = df[df["SECTION"] == "GAMMA"]

# Calculate pass probability
total_students = len(alpha_df)
students_passed = (alpha_df["DV"] >= passing_mark).sum()
pass_probability = students_passed / total_students

# Output the result
print(f"Pass probability for DV in Section Alpha: {pass_probability:.4f}")
# Out:
# Pass probability for DV in Section Alpha: 0.8778

# %%
import pandas as pd

# Load the dataset
file_path = "MIDMARKS.csv"  # Update with the correct file path
df = pd.read_csv(file_path)

# Convert the DV column to numeric, handling errors
df["DV"] = pd.to_numeric(df["DV"], errors="coerce")

# Define the passing mark
passing_mark = 10

# Filter the data for Section Alpha
alpha_df = df[df["SECTION"] == "EPSILON"]

# Calculate pass probability
total_students = len(alpha_df)
students_passed = (alpha_df["DV"] >= passing_mark).sum()
pass_probability = students_passed / total_students

# Output the result
print(f"Pass probability for DV in Section EPSILON: {pass_probability:.4f}")
# Out:
# Pass probability for DV in Section EPSILON: 0.9545

# %%
import pandas as pd
df = pd.read_csv("MIDMARKS.csv")
df = df.dropna(how='all')
subjects = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
df[subjects] = df[subjects].apply(pd.to_numeric, errors='coerce').fillna(0)
if 'SECTION' in df.columns:
    df['SECTION'] = df['SECTION'].str.strip().str.lower()
    def calculate_probabilities(group):
        stats = {'Total Students': len(group)}
        for subject in subjects:
            pass_count = (group[subject] >= 10).sum()
            fail_count = (group[subject] < 10).sum()
            stats[f'{subject} Pass Probability'] = pass_count / len(group)
            stats[f'{subject} Fail Probability'] = fail_count / len(group)
        return pd.Series(stats)
    section_subject_probabilities = df.groupby('SECTION').apply(calculate_probabilities)
    print(section_subject_probabilities)
else:
    print("No 'SECTION' column found in the dataset.")
# Out:
#          Total Students  DV Pass Probability  DV Fail Probability  \
# SECTION
# alpha              90.0             0.811111             0.188889
# beta               90.0             0.811111             0.188889
# delta              90.0             0.844444             0.155556
# epsilon            88.0             0.954545             0.045455
# gamma              90.0             0.877778             0.122222
# omega              90.0             0.888889             0.111111
# sigma              63.0             0.904762             0.095238
# zeta               90.0             0.911111             0.088889
#
#          M-II Pass Probability  M-II Fail Probability  PP Pass Probability  \
# SECTION
# alpha                 0.800000               0.200000             0.866667
# beta                  0.722222               0.277778             0.911111
# delta                 0.500000               0.500000             0.688889
# epsilon               0.272727               0.727273             0.443182
# gamma                 0.488889               0.511111             0.600000
# omega                 0.355556               0.644444             0.822222
# sigma                 0.682540               0.317460             0.809524
# zeta                  0.300000               0.700000             0.444444
#
#          PP Fail Probability  BEEE Pass Probability  BEEE Fail Probability  \
# SECTION
# alpha               0.133333               0.911111               0.088889
# beta                0.088889               0.544444               0.455556
# delta               0.311111               0.488889               0.511111
# epsilon             0.556818               0.806818               0.193182
# gamma               0.400000               0.811111               0.188889
# omega               0.177778               0.766667               0.233333
# sigma               0.190476               0.730159               0.269841
# zeta                0.555556               0.800000               0.200000
#
#          FL Pass Probability  FL Fail Probability  FIMS Pass Probability  \
# SECTION
# alpha               0.988889             0.011111               0.755556
# beta                0.988889             0.011111               0.877778
# delta               0.988889             0.011111               0.955556
# epsilon             0.909091             0.090909               0.750000
# gamma               0.977778             0.022222               0.744444
# omega               0.866667             0.133333               0.922222
# sigma               0.952381             0.047619               0.873016
# zeta                0.833333             0.166667               0.777778
#
#          FIMS Fail Probability
# SECTION
# alpha                 0.244444
# beta                  0.122222
# delta                 0.044444
# epsilon               0.250000
# gamma                 0.255556
# omega                 0.077778
# sigma                 0.126984
# zeta                  0.222222

# %%
(df["BEEE"] > 10).value_counts() / len(df)
# Out:
# True     0.695955
# False    0.304045
# Name: BEEE, dtype: float64

# %%
(df["FL"] > 10).value_counts() / len(df)
# Out:
# True     0.832636
# False    0.167364
# Name: FL, dtype: float64

# %%
df[df["SECTION"]=="ALPHA"].mean()
# Out:
# S.NO       NaN
# SECTION    NaN
# DV         NaN
# M-II       NaN
# PP         NaN
# BEEE       NaN
# FL         NaN
# FIMS       NaN
# dtype: object

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("MIDMARKS.csv")  # Ensure the correct file path

# Convert the "DV" column to numeric (if not already)
df["DV"] = pd.to_numeric(df["DV"], errors="coerce")

# Calculate the sample mean for the "ALPHA" section
alpha_dv_mean = df[df["SECTION"] == "ALPHA"]["DV"].mean()

# %%
alpha_dv_mean
# Out:
# 13.411111111111111

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("MIDMARKS.csv")  # Ensure the correct file path

# Convert the "DV" column to numeric (if not already)
df["DV"] = pd.to_numeric(df["DV"], errors="coerce")

# Calculate the sample mean for the "ALPHA" section
alpha_dv_mean = df[df["SECTION"] == "ALPHA"]["DV"].mean()
population_dv_mean=df["DV"].mean

# %%
population_dv_mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0      12.0
# 1      19.0
# 2      18.0
# 3      15.0
# 4      18.0
#        ...
# 713    19.0
# 714    12.0
# 715    17.0
# 716    12.0
# 717    19.0
# Name: DV, Length: 718, dtype: float64>

# %%
std_data=df[df["SECTION"]=="ALPHA"].std()
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_44508\1348357844.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   std_data=df[df["SECTION"]=="ALPHA"].std()

# %%
std_data
# Out:
# S.NO    26.124701
# DV       4.991891
# dtype: float64

# %%
std_data=df.groupby(['SECTION']).std()

# %%
std_data
# Out:
#               S.NO        DV
# SECTION
# ALPHA    26.124701  4.991891
# BETA     26.124701  3.815992
# DELTA    26.124701  3.804249
# EPSILON  25.547342  2.874735
# GAMMA    26.124701  4.235768
# OMEGA    26.124701  4.487007
# SIGMA    18.330303  3.916465
# ZETA           NaN  3.538386

# %% [markdown]
# The analysis provides valuable insights into student performance by comparing different sections and subjects. The visualizations and statistical tests highlight trends, such as score distributions and pass rates. By identifying students at risk of failing and highlighting areas where performance improvement is needed, this script serves as a useful tool for educators to make data-driven decisions. Further enhancements could include predictive modeling to anticipate student outcomes based on previous performances.
